# %%
import pandas as pd
PATH = "~/data/movies/merge/dailyboxoffice/dt=20240101"
df = pd.read_parquet(PATH)
df
# Out:
#    rankOldAndNew   movieCd                               movieNm      openDt  \
# 0            OLD  20203702                            노량: 죽음의 바다  2023-12-20
# 1            OLD  20203702                            노량: 죽음의 바다  2023-12-20
# 2            OLD  20212866                                 서울의 봄  2023-11-22
# 3            OLD  20212866                                 서울의 봄  2023-11-22
# 4            OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 5            OLD  20236146  신차원! 짱구는 못말려 더 무비 초능력 대결전 ~날아라 수제김밥~  2023-12-22
# 6            OLD  20235735                          아쿠아맨과 로스트 킹덤  2023-12-20
# 7            OLD  20235735                          아쿠아맨과 로스트 킹덤  2023-12-20
# 8            OLD  20235596                            트롤: 밴드 투게더  2023-12-20
# 9            OLD  20235596                            트롤: 밴드 투게더  2023-12-20
# 10           OLD  20234673                      뽀로로 극장판 슈퍼스타 대모험  2023-12-13
# ...
